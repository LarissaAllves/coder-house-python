# %% [markdown]
# Utilizando a base "realtor-data.csv" (link kaggle) gerar uma amostra com os seguintes requisitos:
# amostra aleatória
# com 1.000 registros, sendo:
# 250 do estado de Massachusetts
# 250 do estado de Puerto Rico
# 250 do estado de Connecticut
# 250 dos estados Rhode Island e New York
# somente casas for_sale
# sem duplicidades de status, city, state e price
# na remoção de duplicados priorizar as casas maiores.
# Valide a amostra criada.

# %%
 import pandas as pd 

 df=pd.read_csv('realtor-data.csv')
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          100000 non-null  object
#  1   bed             75050 non-null   float64
#  2   bath            75112 non-null   float64
#  3   acre_lot        85987 non-null   float64
#  4   city            99948 non-null   object
#  5   state           100000 non-null  object
#  6   zip_code        99805 non-null   float64
#  7   house_size      75082 non-null   float64
#  8   prev_sold_date  28745 non-null   object
#  9   price           100000 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 7.6+ MB

# %%
df.describe(include='all')

# df.head()
# Out:
#           status           bed          bath       acre_lot      city  \
# count     100000  75050.000000  75112.000000   85987.000000     99948
# unique         2           NaN           NaN            NaN       525
# top     for_sale           NaN           NaN            NaN  San Juan
# freq       99819           NaN           NaN            NaN      4788
# mean         NaN      3.701013      2.494595      13.613473       NaN
# std          NaN      2.091372      1.573324     840.143878       NaN
# min          NaN      1.000000      1.000000       0.000000       NaN
# 25%          NaN      3.000000      2.000000       0.190000       NaN
# 50%          NaN      3.000000      2.000000       0.510000       NaN
# 75%          NaN      4.000000      3.000000       2.000000       NaN
# max          NaN     86.000000     56.000000  100000.000000       NaN
#
#                 state      zip_code    house_size prev_sold_date         price
# ...

# %%
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df_filtro=df[df.status=='for_sale'].copy()
df_filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99819 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status          99819 non-null  object
#  1   bed             74869 non-null  float64
#  2   bath            75112 non-null  float64
#  3   acre_lot        85987 non-null  float64
#  4   city            99767 non-null  object
#  5   state           99819 non-null  object
#  6   zip_code        99624 non-null  float64
#  7   house_size      74901 non-null  float64
#  8   prev_sold_date  28745 non-null  object
#  9   price           99819 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 8.4+ MB

# %%
df_filtro.sort_values('house_size', ascending=False).drop_duplicates(subset=['status', 'city', 'state', 'price'], inplace=True)
df_filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99819 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status          99819 non-null  object
#  1   bed             74869 non-null  float64
#  2   bath            75112 non-null  float64
#  3   acre_lot        85987 non-null  float64
#  4   city            99767 non-null  object
#  5   state           99819 non-null  object
#  6   zip_code        99624 non-null  float64
#  7   house_size      74901 non-null  float64
#  8   prev_sold_date  28745 non-null  object
#  9   price           99819 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 8.4+ MB

# %%
df_filtro.reset_index(drop=True, inplace=True)
df_filtro.state.value_counts()
# Out:
# state
# Massachusetts     52513
# Puerto Rico       24679
# Connecticut       12178
# Virgin Islands     2573
# Rhode Island       2401
# New Hampshire      2232
# New York           1874
# Vermont            1324
# South Carolina       24
# Tennessee            16
# Virginia              3
# New Jersey            2
# Name: count, dtype: int64

# %%
df_filtro.dropna(subset='state', inplace=True)
df_filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99819 entries, 0 to 99818
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status          99819 non-null  object
#  1   bed             74869 non-null  float64
#  2   bath            75112 non-null  float64
#  3   acre_lot        85987 non-null  float64
#  4   city            99767 non-null  object
#  5   state           99819 non-null  object
#  6   zip_code        99624 non-null  float64
#  7   house_size      74901 non-null  float64
#  8   prev_sold_date  28745 non-null  object
#  9   price           99819 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 7.6+ MB

# %%
amostra_df=pd.DataFrame()

amostra_df=pd.concat([amostra_df,df[df.state=='Massachusetts'].sample(n=250, random_state=25)])
amostra_df=pd.concat([amostra_df,df[df.state=='Puerto Rico'].sample(n=250, random_state=25)])
amostra_df=pd.concat([amostra_df,df[df.state=='Connecticut'].sample(n=250, random_state=25)])
amostra_df=pd.concat([amostra_df,df[(df.state=='Rhode Island')|(df.state=='New York')].sample(n=250, random_state=25)])
amostra_df
# Out:
#          status  bed  bath  acre_lot         city          state  zip_code  \
# 41252  for_sale  8.0   3.0      0.14  Springfield  Massachusetts    1108.0
# 55833  for_sale  NaN   NaN      2.00    Blandford  Massachusetts    1008.0
# 51680  for_sale  4.0   1.0      0.24       Ludlow  Massachusetts    1056.0
# 59660  for_sale  NaN   NaN     12.30   Charlemont  Massachusetts    1339.0
# 53011  for_sale  4.0   3.0      1.70  North Adams  Massachusetts    1247.0
# ...         ...  ...   ...       ...          ...            ...       ...
# 93798  for_sale  4.0   2.0      0.11   Providence   Rhode Island    2905.0
# 93924  for_sale  3.0   3.0      0.50   Cumberland   Rhode Island    2864.0
# 94449  for_sale  9.0   3.0      0.09     Johnston   Rhode Island    2919.0
# 64275  for_sale  NaN   NaN    133.74       Canaan       New York   12029.0
# 95240  for_sale  NaN   NaN      3.94     Coventry   Rhode Island    2816.0
#
#        house_size prev_sold_date     price
# ...

# %%
amostra_df_filtro=pd.DataFrame()

amostra_df_filtro=pd.concat([amostra_df_filtro,df_filtro[df_filtro.state=='Massachusetts'].sample(n=250, random_state=25)])
amostra_df_filtro=pd.concat([amostra_df_filtro,df_filtro[df_filtro.state=='Puerto Rico'].sample(n=250, random_state=25)])
amostra_df_filtro=pd.concat([amostra_df_filtro,df_filtro[df_filtro.state=='Connecticut'].sample(n=250, random_state=25)])
amostra_df_filtro=pd.concat([amostra_df_filtro,df_filtro[(df_filtro.state=='Rhode Island')|(df_filtro.state=='New York')].sample(n=250, random_state=25)])
amostra_df_filtro
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 48392  for_sale  4.0   2.0      0.11      Agawam  Massachusetts    1001.0
# 28523  for_sale  NaN   NaN      0.64      Becket  Massachusetts    1223.0
# 97180  for_sale  6.0   3.0      0.12     Gardner  Massachusetts    1440.0
# 91988  for_sale  3.0   1.0      1.31  Sturbridge  Massachusetts    1518.0
# 98782  for_sale  8.0   5.0      0.23     Spencer  Massachusetts    1562.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 93639  for_sale  4.0   2.0      0.11  Providence   Rhode Island    2905.0
# 93765  for_sale  3.0   3.0      0.50  Cumberland   Rhode Island    2864.0
# 94279  for_sale  9.0   3.0      0.09    Johnston   Rhode Island    2919.0
# 64275  for_sale  NaN   NaN    133.74      Canaan       New York   12029.0
# 95070  for_sale  NaN   NaN      3.94    Coventry   Rhode Island    2816.0
#
#        house_size prev_sold_date     price
# ...

# %%
df.status.value_counts(normalize=True)*100
# Out:
# status
# for_sale          99.819
# ready_to_build     0.181
# Name: proportion, dtype: float64

# %%
amostra_df.status.value_counts(normalize=True)*100
# Out:
# status
# for_sale          99.9
# ready_to_build     0.1
# Name: proportion, dtype: float64
